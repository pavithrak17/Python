# %% [markdown]
# <a href="https://colab.research.google.com/github/pavithrak17/Python/blob/master/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What will the following code output if age equals 16? Python if age is lesser or equal to 18 Print you are eligible to vote Print you are not eligible to vote The age is greater or equal to 18, not lesser or equal to 18

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 16
# You are not eligible to vote

# %% [markdown]
# How can you combine if-else statements and loops in Python by using if-else inside a loop by using a loop inside if-else statement both A and B, neither A nor B?

# %%
for i in range(5):
    if i % 2 == 0:
        print(i, "is even")
    else:
        print(i, "is odd")
# Out:
# 0 is even
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even

# %%
count = 5
if count < 0:
    for i in range(count):
        print("Count is", i)
else:
    print("Count is not lesser than zero")
# Out:
# Count is not lesser than zero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def greet_user(name):
    # Check if the input is a non-empty string and contains only alphabetic characters
    if isinstance(name, str) and name.isalpha() and len(name) > 0:
        return f"Hello, {name}!"
    else:
        return "Invalid input. Please enter a valid name."

name = input("Enter your name: ")
greeting = greet_user(name)
print(greeting)
# Out:
# Enter your name: pavi
# Hello, pavi!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def calculate_age(birth_year):
    # Check if birth_year is a valid integer within the range 1900 to 2024
    if isinstance(birth_year, int) and 1900 <= birth_year <= 2024:
        current_year = 2024
        age = current_year - birth_year
        return age
    else:
        return "Invalid input. Please enter a valid birth year between 1900 and 2023."

birth_year = int(input("Enter your birth year: "))
age = calculate_age(birth_year)
print("Your age is:", age)
# Out:
# Enter your birth year: 2003
# Your age is: 21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def add_numbers(num1, num2):
    # Check if num1 and num2 are within the valid range
    if isinstance(num1, int) and isinstance(num2, int) and -100000 <= num1 <= 100000 and -100000 <= num2 <= 100000:
        return num1 + num2
def add_numbers(num1, num2):
    # Check if num1 and num2 are within the valid range
    if isinstance(num1, int) and isinstance(num2, int) and -100000 <= num1 <= 100000 and -100000 <= num2 <= 100000:
        return num1 + num2
    else:
        return "Invalid input. Please enter integers between -100000 and 100000."
print(add_numbers(num1=5, num2=10))
# Out:
# 15

# %% [markdown]
# Write a Python function is prime_or_even_odd(n) that takes an integer n as input and performs the following:
# If n is a prime number, return True.
# If n is not a prime number, return "Even" if n is even, or "Odd" if n is odd.
# Constraint
# The input will be an integer between 1 and 1000.

# %%
def prime_or_even_odd(n):
    # Check if n is prime
    if n > 1:
        for i in range(2, n):
            if n % i == 0:
                return "Even" if n % 2 == 0 else "Odd"
        return True  # n is prime
    return "Odd"  # n is 1, which is odd


print(prime_or_even_odd(7))
print(prime_or_even_odd(10))
print(prime_or_even_odd(9))
# Out:
# True
# Even
# Odd

# %% [markdown]
# Create a Python function grade(score) that takes a student's score (integer) as input and returns a grade as per the following rules:
# A: if score >= 90
# B: if score >= 80
# C: if score >= 70
# D: if score >= 60
# F: if score < 60
# Constraint
# Input: score must be an integer between 0 and 100 inclusive.
# Output: Returns a single character string: 'A', 'B', 'C', 'D', or 'F'.
# Errors:
# Raise ValueError if score is out of range (0-100).
# Raise TypeError if score is not an integer.

# %%
def grade(score):
    # Check if score is an integer
    if not isinstance(score, int):
        raise TypeError("Score must be an integer.")

    # Check if score is within the valid range
    if score < 0 or score > 100:
        raise ValueError("Score must be between 0 and 100.")

    # Determine the grade based on the score
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'F'

print(grade(85))
print(grade(92))
# Out:
# B
# A

# %% [markdown]
# Write a Python function categorize_temperature(temp) that takes a temperature (in Celsius) as input and returns:
# "Hot" if the temperature is above 30,
# "Warm" if the temperature is between 20 and 30 (inclusive),
# "Cool" if the temperature is between 10 and 19 (inclusive),
# "Cold" if the temperature is below 10.
# Constraint
# The input will be a float between -50.0 and 50.0

# %%
def categorize_temperature(temp):
    if temp > 30:
        return "Hot"
    elif 20 <= temp <= 30:
        return "Warm"
    elif 10 <= temp <= 19:
        return "Cool"
    else:
        return "Cold"

# Example usage
print(categorize_temperature(35.5))
print(categorize_temperature(25.0))
print(categorize_temperature(15.0))
print(categorize_temperature(5.0))
# Out:
# Hot
# Warm
# Cool
# Cold

# %% [markdown]
# Write a Python function multiplication_table(number) that takes a number as input and prints
# its multiplication table from 1 to 10.
# Constraint
# The input will be an integer between 1 and 20.

# %%
def multiplication_table(number):
    for i in range(1, 11):
        print(f"{number} x {i} = {number * i}")

# Example usage
multiplication_table(5)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# Write a Python function greet_people(person_dict) that takes a dictionary as input where each
# key is a string (the person's name) and each value is an integer (the person's age). The function
# should print a message for each name and age in the dictionary in the format:
# Hello, {name}! You are {age} years old.
# Constraint
# The input dictionary will contain between 1 and 10 entries.
# Each key (name) will be a string of length 1 to 50.
# Each value (age) will be an integer between 1 and 100.

# %%
def greet_people(person_dict):
    for name, age in person_dict.items():
        print(f"Hello, {name}! You are {age} years old.")

# Example usage
people = {
    "Alice": 30,
    "Bob": 25,
    "Charlie": 40
}

greet_people(people)
# Out:
# Hello, Alice! You are 30 years old.
# Hello, Bob! You are 25 years old.
# Hello, Charlie! You are 40 years old.

# %% [markdown]
# Write a Python function calculate_area(length, width) that takes two
# inputs: two integers length and width, and returns the area of a
# rectangle.
# Constraint
# Both length and width will be positive integers between 1 and 1000.

# %%
def calculate_area(length, width):
    return length * width

# Example usage
print(calculate_area(10, 5))
print(calculate_area(7, 3))
# Out:
# 50
# 21

# %% [markdown]
# Write a Python function add_to_list(my_list, item) that takes a list
# my_list and an item item. The function should append the item to
# the list and return the updated list.
# Constraint
# The list will have a maximum length of 10.
# The item can be any valid Python data type.

# %%
def add_to_list(my_list, item):
    if len(my_list) < 10:
        my_list.append(item)
    return my_list

# Example usage
print(add_to_list([1, 2, 3], 4))
print(add_to_list(['a', 'b'], 'c'))
# Out:
# [1, 2, 3, 4]
# ['a', 'b', 'c']

# %% [markdown]
# Write a Python function is_in_set(my_set, item) that takes a set
# my_set and a variable item. The function should return True if the
# item exists in the set, otherwise return False.
# Constraint
# The set will contain up to 10 elements.

# %%
def is_in_set(my_set, item):
    return item in my_set

# Example usage
print(is_in_set({1, 2, 3}, 2))
print(is_in_set({'a', 'b', 'c'}, 'd'))
# Out:
# True
# False

# %% [markdown]
# Write a Python function
# create_data_structures() that performs the
# following tasks:
# 1. Create a list called my_list containing the
# numbers [1, 2, 3].
# 2. Create a tuple called my_tuple
# containing the strings ("apple", "banana",
# "cherry").
# 3. Create a dictionary called my_dict with
# keys as {"name": "Alice", "age": 25}.
# 4. Create a set called my_set with values {1,
# 2, 3}.
# Your function should return all four data
# structures as a tuple in the order: (list,
# tuple, dictionary, set).
# Constraint
# The list will contain exactly 3 integers.
# The tuple will contain exactly 3 strings.
# The dictionary will have two key-value
# pairs: one string (name) and one integer
# (age).
# The set will contain 3 unique integers.

# %%
def create_data_structures():
    # List with exactly three integers
    my_list = [1, 2, 3]

    # Tuple with exactly three strings
    my_tuple = ("apple", "banana", "cherry")

    # Dictionary with specified key-value pairs
    my_dict = {"name": "Alice", "age": 25}

    # Set with three unique integers
    my_set = {1, 2, 3}

    # Return all four data structures as a tuple
    return my_list, my_tuple, my_dict, my_set

# Call the function and store the returned values
result = create_data_structures()

# Print the returned values
print(result)
# Out:
# ([1, 2, 3], ('apple', 'banana', 'cherry'), {'name': 'Alice', 'age': 25}, {1, 2, 3})

# %% [markdown]
# Write a Python function get_second_color(colors) that takes a tuple
# of colors as input and returns the second color in the tuple.
# Constraint
# The tuple will contain at least two colors, each as a string.

# %%
def get_second_color(colors):
    return colors[0]
my_colors = ("red", "green", "blue")
second_color = get_second_color(my_colors)
print(second_color)
# Out:
# red

# %% [markdown]
# Write a Python function get_capital(capitals, country) that takes a
# dictionary capitals and a string country, and returns the capital of
# that country.
# Constraint
# The dictionary will contain up to 5 country-capital pairs.
# The country input will be a string with a length between 1 and 30.

# %%
capitals = {
    "USA": "Washington D.C.",
    "France": "Paris",
    "Japan": "Tokyo",
    "Germany": "Berlin"
}

def get_capital(capitals, country):
    return capitals.get(country)
print(capitals)
country = "USA"
capital = get_capital(capitals, country)
print(f"The capital of {country} is {capital}.")
# Out:
# {'USA': 'Washington D.C.', 'France': 'Paris', 'Japan': 'Tokyo', 'Germany': 'Berlin'}
# The capital of USA is Washington D.C..

# %% [markdown]
# Write a Python function update_sports(sports) that takes a set of
# sports, adds "cricket" to it, removes "tennis", and returns the
# updated set.
# Constraint
# The set will have a maximum of 5 sports.

# %%
def update_sports(sports):
    sports.add("cricket")
    sports.discard("tennis")
    return sports

# Create a sample set of sports
my_sports = {"football", "tennis", "basketball"}

# Call the update_sports function
updated_sports = update_sports(my_sports)

# Print the updated set
print(updated_sports)
# Out:
# {'football', 'cricket', 'basketball'}

# %% [markdown]
# Write a Python function math_operations(num: int) -> dict that takes a user input integer num
# and returns a dictionary containing:
# The square root of num.
# The sine of 90 degrees.
# The factorial of num.
# Constraint
# num will be a non-negative integer between 1 and 100.
# For sine calculation, convert degrees to radians using the math.radians() function.
# Use the math module to perform these operations.

# %%
import math

def math_operations(num: int) -> dict:
    # Calculating square root of num
    square_root = math.sqrt(num)

    # Calculating sine of 90 degrees in radians
    sine_90 = math.sin(math.radians(90))

    # Calculating factorial of num
    factorial = math.factorial(num)

    # Returning results as a dictionary
    return {
        "square_root": square_root,
        "sine_90_degrees": sine_90,
        "factorial": factorial
    }

# Example usage
result = math_operations(5)
print(result)
# Out:
# {'square_root': 2.23606797749979, 'sine_90_degrees': 1.0, 'factorial': 120}

# %% [markdown]
# Write a Python function get_current_datetime() -> dict that returns a dictionary containing:
# The current date.
# The current time.
# The current date and time formatted as YYYY-MM-DD HH:MM:SS.
# Constraint
# Use the datetime module to get the current date and time.
# The function should not accept any arguments.

# %%
from datetime import datetime

def get_current_datetime() -> dict:
    now = datetime.now()
    current_date = now.date()
    current_time = now.time()
    formatted_datetime = now.strftime("%Y-%m-%d %H:%M:%S")

    return {
        "current_date": current_date,
        "current_time": current_time,
        "formatted_datetime": formatted_datetime
    }

# Example usage
result = get_current_datetime()
print(result)
# Out:
# {'current_date': datetime.date(2024, 10, 27), 'current_time': datetime.time(13, 10, 14, 489511), 'formatted_datetime': '2024-10-27 13:10:14'}

# %% [markdown]
# Write a Python function file_system_operations() -> dict that
# performs the following operations using the os module and returns
# a dictionary with:
# The current working directory.
# A list of files in the current directory.
# A confirmation message after creating a new directory called
# 'new_folder'.
# Constraint
# Use the os module for all file system operations.
# The function should not accept any arguments.

# %%
import os

def file_system_operations() -> dict:
    current_directory = os.getcwd()
    files_list = os.listdir(current_directory)

    if not os.path.exists('new_folder'):
        os.mkdir('new_folder')
        confirmation_message = "Directory 'new_folder' created."
    else:
        confirmation_message = "Directory 'new_folder' already exists."

    return {
        "current_working_directory": current_directory,
        "files_in_directory": files_list,
        "confirmation_message": confirmation_message
    }

# Example usage
result = file_system_operations()
print(result)
# Out:
# {'current_working_directory': '/content', 'files_in_directory': ['.config', 'new_folder', 'sample_data'], 'confirmation_message': "Directory 'new_folder' already exists."}

# %% [markdown]
# Write a Python function numpy_operations() -> dict that performs
# the following operations using the NumPy library:
# Create a NumPy array [1, 2, 3, 4, 5].
# Add 10 to each element in the array.
# Calculate and return the mean of the original array.
# The function should return a dictionary with the modified array and
# the mean.
# Constraint
# Use the numpy library for all operations.
# The function should not accept any arguments.

# %%
import numpy as np

def numpy_operations() -> dict:
    original_array = np.array([1, 2, 3, 4, 5])
    modified_array = original_array + 10
    mean_value = np.mean(original_array)

    return {
        "modified_array": modified_array.tolist(),
        "mean": mean_value
    }

# Example usage
result = numpy_operations()
print(result)
# Out:
# {'modified_array': [11, 12, 13, 14, 15], 'mean': 3.0}

# %% [markdown]
# Write a Python function pandas_operations() -> dict that
# performs the following operations using the Pandas library:
# Create a DataFrame with the following data:
# {"Name": ["Alice", "Bob", "Charlie"], "Age": [25, 30, 35]}
# Filter the DataFrame to include only rows where the Age is greater
# than 28.
# Calculate the sum of the Age column.
# The function should return a dictionary containing the filtered
# DataFrame and the sum of ages.
# Constraint
# Use the pandas library for data manipulation.
# The function should not accept any arguments.

# %%
import pandas as pd

def pandas_operations() -> dict:
    data = {"Name": ["Alice", "Bob", "Charlie"], "Age": [25, 30, 35]}
    df = pd.DataFrame(data)

    filtered_df = df[df['Age'] > 28]
    age_sum = df['Age'].sum()

    return {
        "filtered_dataframe": filtered_df.to_dict(orient='records'),
        "sum_of_ages": age_sum
    }

# Example usage
result = pandas_operations()
print(result)
# Out:
# {'filtered_dataframe': [{'Name': 'Bob', 'Age': 30}, {'Name': 'Charlie', 'Age': 35}], 'sum_of_ages': 90}

# %% [markdown]
# Write a Python function divide_numbers(num1, num2) that takes
# two numbers as input and returns their division.
# If the second number is zero, raise a ZeroDivisionError and handle it
# by returning the message "Error: Division by zero is not allowed."
# Constraint
# num1 and num2 are integers between -100 and 100.
# You must handle the ZeroDivisionError explicitly.

# %%
def divide_numbers(num1: int, num2: int) -> str:
    try:
        result = num1 / num2
        return result
    except ZeroDivisionError:
        return "Error: Division by zero is not allowed."

# Example usage
result1 = divide_numbers(10, 2)
print(result1)  # Output: 5.0

result2 = divide_numbers(10, 0)
print(result2)  # Output: Error: Division by zero is not allowed.
# Out:
# 5.0
# Error: Division by zero is not allowed.

# %% [markdown]
# Write a Python function get_valid_number() that prompts the user
# to input a number and returns the integer value.
# If the user provides a non-integer input, raise a ValueError and
# handle it by returning the message "Error: That's not a valid
# number."
# Constraint
# The input should be a string that can be converted to an integer.
# You must handle the ValueError explicitly.

# %%
def get_valid_number() -> int:
    try:
        user_input = input("Please enter a number: ")
        return int(user_input)
    except ValueError:
        return "Error: That's not a valid number."

# Example usage
result = get_valid_number()
print(result)
# Out:
# Please enter a number: 1
# 1

# %% [markdown]
# Write a Python function safe_list_access(my_list, index) that takes a
# list my_list and an integer index as input and returns the element at
# the given index.
# If the index is out of range, raise an IndexError and handle it by
# returning the message "Error: Index out of range."
# Constraint
# my_list will contain at least 1 integer and at most 200 integers.
# index is an integer that can be any value (positive or negative).

# %%
def safe_list_access(my_list, index):
    try:
        return my_list[index]
    except IndexError:
        return "Error: Index out of range."

# Example usage
my_list = [10, 20, 30, 40, 50]
result1 = safe_list_access(my_list, 2)  # Valid index
print(result1)  # Output: 30

result2 = safe_list_access(my_list, 10)  # Out of range index
print(result2)  # Output: Error: Index out of range.

result3 = safe_list_access(my_list, -1)  # Valid negative index
print(result3)  # Output: 50

result4 = safe_list_access(my_list, -6)  # Out of range negative index
print(result4)  # Output: Error: Index out of range.
# Out:
# 30
# Error: Index out of range.
# 50
# Error: Index out of range.

# %% [markdown]
# Write a Python function check_positive(number) that takes an
# integer number as input.
# If the number is negative, raise a ValueError with the message
# "Negative numbers are not allowed!" and handle it by returning the
# message. Otherwise, return the number.
# Constraint
# The input number will be an integer between -100 and 100.

# %%
def check_positive(number: int) -> int:
    try:
        if number < 0:
            raise ValueError("Negative numbers are not allowed!")
        return number
    except ValueError as e:
        return str(e)

# Example usage
result1 = check_positive(10)  # Positive number
print(result1)  # Output: 10

result2 = check_positive(-5)  # Negative number
print(result2)  # Output: Negative numbers are not allowed!
# Out:
# 10
# Negative numbers are not allowed!

# %% [markdown]
# Write a Python function process_input(data) that takes a string data
# as input and performs the following actions:
# 1. If the string is empty, return the message "Error: Empty input
# provided.".
# 2. If the string exceeds 255 characters, return the message "Error:
# Input exceeds maximum length.".
# 3. If the string contains any numeric characters, return the message
# "Error: Input contains invalid characters.".
# 4. If none of the above conditions apply, return the message "Input
# processed successfully.".
# 5. \
# Program should handle all above scenarios by raising a CustomError
# Finally, ensure the message "Program execution completed." is
# always printed.
# Constraint
# data is a string with a maximum length of 255 characters.

# %%
class CustomError(Exception):
    pass

def process_input(data: str) -> str:
    try:
        if not data:
            raise CustomError("Error: Empty input provided.")
        if len(data) > 255:
            raise CustomError("Error: Input exceeds maximum length.")
        if any(char.isdigit() for char in data):
            raise CustomError("Error: Input contains invalid characters.")

        return "Input processed successfully."
    except CustomError as e:
        return str(e)
    finally:
        print("Program execution completed.")

# Example usage
result1 = process_input("")  # Empty input
print(result1)

result2 = process_input("a" * 256)  # Exceeds maximum length
print(result2)

result3 = process_input("Hello123")  # Contains numeric characters
print(result3)

result4 = process_input("Hello, World!")  # Valid input
print(result4)
# Out:
# Program execution completed.
# Error: Empty input provided.
# Program execution completed.
# Error: Input exceeds maximum length.
# Program execution completed.
# Error: Input contains invalid characters.
# Program execution completed.
# Input processed successfully.

# %%
class Book:
    def __init__(self, title: str, author: str):
        if not title or not author:
            raise ValueError("Title and author must be non-empty strings.")
        self.title = title
        self.author = author

    def display_info(self):
        print(f"Title: {self.title}, Author: {self.author}")

# Example usage
book1 = Book("To Kill a Mockingbird", "Harper Lee")
book1.display_info()
# Out:
# Title: To Kill a Mockingbird, Author: Harper Lee

# %% [markdown]
# Create a class named Employee that contains a private attribute
# called __ salary (a float).
# Implement a method get_salary that prints and returns the current
# salary, and a method set_salary that updates the salary, but prints
# the updated salary.
# You should create an object of the Employee class and first call the
# get method, and then the set method.
# Expected Output:
# get_salary should print the current salary.
# set_salary should only update and print the new salary if it's greater
# than 0.
# Constraint
# The salary should always be a positive number.
# The setter should prevent negative values and zero from being set
# as the salary.
# The getter should return the salary as a floating-point number.

# %%
class Employee:
    def __init__(self, salary: float):
        if salary <= 0:
            raise ValueError("Salary must be a positive number.")
        self.__salary = salary

    def get_salary(self) -> float:
        print(f"Current salary: {self.__salary}")
        return self.__salary

    def set_salary(self, new_salary: float):
        if new_salary <= 0:
            print("Error: Salary must be a positive number.")
        else:
            self.__salary = new_salary
            print(f"Updated salary: {self.__salary}")

# Example usage
employee = Employee(50000.0)

# Get current salary
current_salary = employee.get_salary()

# Set a new salary
employee.set_salary(55000.0)

# Try to set a negative salary
employee.set_salary(-1000.0)
# Out:
# Current salary: 50000.0
# Updated salary: 55000.0
# Error: Salary must be a positive number.

# %% [markdown]
# Create a base class named Vehicle with a method move that prints
# "Vehicle is moving".
# Then, create a subclass Car that overrides the move method to print
# "Car is driving".
# Instantiate an object of the Vehicle class and call the move method.
# Also, instantiate an object of the Car class and call the move
# method.
# Expected Output:
# The move method of Vehicle should print "Vehicle is moving".
# The move method of Car should print "Car is driving".
# Constraint
# The move method in both the base class and the subclass should
# not return any values, only print the output.
# Ensure that the subclass method properly overrides the base class
# method.

# %%
class Vehicle:
    def move(self):
        print("Vehicle is moving")

class Car(Vehicle):
    def move(self):
        print("Car is driving")

# Example usage
vehicle = Vehicle()
vehicle.move()  # Output: Vehicle is moving

car = Car()
car.move()  # Output: Car is driving
# Out:
# Vehicle is moving
# Car is driving

# %% [markdown]
# Create two classes, Dog and Cat, each having a method named
# sound.
# In the Dog class, sound should print "Bark", and in the Cat class,
# sound should print "Meow".
# Write a function make_sound that takes an animal object (either a
# Dog or Cat) and calls its sound method.
# Test your function with both a Dog and a Cat object.
# Expected Output:
# The sound method of the Dog class should print "Bark".
# The sound method of the Cat class should print "Meow".
# The make_sound function should correctly call the sound method of
# either class.
# Constraint
# The sound method in both classes should not return any values,
# only print the output.
# The make_sound function should work for any object that has a
# sound method (i.e ., it should be polymorphic).

# %%
class Dog:
    def sound(self):
        print("Bark")

class Cat:
    def sound(self):
        print("Meow")

def make_sound(animal):
    animal.sound()

# Example usage
dog = Dog()
cat = Cat()

make_sound(dog)  # Output: Bark
make_sound(cat)  # Output: Meow
# Out:
# Bark
# Meow

# %% [markdown]
# Write a Python class called Laptop that has two attributes: brand (a
# string) and ram (an integer representing RAM in GB).
# Implement a method upgrade_ram that takes an additional RAM
# value (integer) and adds it to the existing RAM. After upgrading,
# the method prints the updated RAM.
# Expected Output:
# The upgrade_ram method should print the updated RAM value in
# the format: "RAM upgraded to <new_ram>GB".
# Constraint
# The ram attribute must be a positive integer.
# The upgrade_ram method should accept only positive integers and
# should not allow negative or zero values.

# %%
class Laptop:
    def __init__(self, brand: str, ram: int):
        if ram <= 0:
            raise ValueError("RAM must be a positive integer.")
        self.brand = brand
        self.ram = ram

    def upgrade_ram(self, additional_ram: int):
        if additional_ram <= 0:
            print("Error: Additional RAM must be a positive integer.")
            return

        self.ram += additional_ram
        print(f"RAM upgraded to {self.ram}GB")

# Example usage
laptop = Laptop("Dell", 8)

# Upgrade RAM
laptop.upgrade_ram(4)  # Output: RAM upgraded to 12GB

# Attempt to upgrade with invalid RAM
laptop.upgrade_ram(-2)  # Output: Error: Additional RAM must be a positive integer.
# Out:
# RAM upgraded to 12GB
# Error: Additional RAM must be a positive integer.
